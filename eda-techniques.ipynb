# %% [markdown]
# # Univariate,bivariate,multivariate analysis

# %%
df1 = pd.read_csv("C:\\Users\\admin\PP_programs\DataRepo\iris.csv")

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1.shape
# Out:
# (150, 6)

# %% [markdown]
# # univariate

# %%
df_setosa = df1.loc[df1["Species"]=="Iris-setosa"]
df_setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df_versicolor = df1.loc[df1["Species"]=="Iris-versicolor"]
df_virginica = df1.loc[df1["Species"]=="Iris-virginica"]

# %%
df_versicolor
df_virginica
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
plt.plot(df_setosa["SepalLengthCm"],np.zeros_like(df_setosa["SepalLengthCm"]),"o")
plt.plot(df_versicolor["SepalLengthCm"],np.zeros_like(df_versicolor["SepalLengthCm"]),"d")
plt.plot(df_verginica["SepalLengthCm"],np.zeros_like(df_verginica["SepalLengthCm"]),"s")

# %% [markdown]
# # Bivariate

# %%
sns.FacetGrid(df1,hue="Species",height=6).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %% [markdown]
# # Multivariate

# %%
df2 = df1.iloc[:,1:]
df2.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df2,hue="Species",height=4)
